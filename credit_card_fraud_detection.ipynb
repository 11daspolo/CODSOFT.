# %% [markdown]
# <a href="https://colab.research.google.com/github/11daspolo/CODSOFT./blob/main/credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import some libreries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#import dataset
credit_card_dataset = pd.read_csv('/content/sample_data/creditcard.csv')
credit_card_dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_dataset.sample()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 165947  117760.0  1.979455 -0.422004 -0.443785  0.382294 -0.455789 -0.036225
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 165947 -0.654308  0.052656  1.432208  ...  0.189855  0.777253  0.140716
#
#             V24       V25       V26       V27       V28  Amount  Class
# 165947  0.63282 -0.070215 -0.237329  0.040574 -0.030089   12.99    0.0
#
# [1 rows x 31 columns]

# %%
#credit card data information
credit_card_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227811 entries, 0 to 227810
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    227811 non-null  float64
#  1   V1      227811 non-null  float64
#  2   V2      227811 non-null  float64
#  3   V3      227811 non-null  float64
#  4   V4      227811 non-null  float64
#  5   V5      227811 non-null  float64
#  6   V6      227811 non-null  float64
#  7   V7      227811 non-null  float64
#  8   V8      227811 non-null  float64
#  9   V9      227811 non-null  float64
#  10  V10     227811 non-null  float64
#  11  V11     227811 non-null  float64
#  12  V12     227811 non-null  float64
#  13  V13     227811 non-null  float64
#  14  V14     227811 non-null  float64
#  15  V15     227811 non-null  float64
#  16  V16     227811 non-null  float64
#  17  V17     227811 non-null  float64
#  18  V18     227811 non-null  float64
#  19  V19     227811 non-null  float64
#  20  V20     227811 non-null  float64
#  21  V21     227811 non-null  float64
#  22  V22     227811 non-null  float64
#  23  V23     227811 non-null  float64
#  24  V24     227811 non-null  float64
#  25  V25     227811 non-null  float64
#  26  V26     227811 non-null  float64
#  27  V27     227811 non-null  float64
#  28  V28     227811 non-null  float64
#  29  Amount  227810 non-null  float64
#  30  Class   227810 non-null  float64
# dtypes: float64(31)
# memory usage: 53.9 MB

# %%
# checking the number of missing values in each column
credit_card_dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit & fraudulent transaction
dataset['Class'].value_counts()
# Out:
# 0.0    185915
# 1.0       368
# Name: Class, dtype: int64

# %%
legit = credit_card_data[credit_card_dataset.Class==0]
fraud = credit_card_data[credit_card_dataset['Class']==1]
# Out:
# <ipython-input-38-7a3cde634aed>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   legit = credit_card_data[credit_card_dataset.Class==0]
# <ipython-input-38-7a3cde634aed>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fraud = credit_card_data[credit_card_dataset['Class']==1]

# %%
fraud['Class']
# Out:
# 541      1.0
# 623      1.0
# 4920     1.0
# 6108     1.0
# 6329     1.0
#         ...
# 46998    1.0
# 47802    1.0
# 48094    1.0
# 50211    1.0
# 50537    1.0
# Name: Class, Length: 150, dtype: float64

# %%
# statistical measurement
legit.Amount.describe()
# Out:
# count    51440.000000
# mean        94.000267
# std        253.580381
# min          0.000000
# 25%          7.680000
# 50%         25.390000
# 75%         86.002500
# max      12910.930000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     150.000000
# mean       98.848400
# std       232.056904
# min         0.000000
# 25%         1.000000
# 50%         8.370000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
credit_card_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    79054.125738 -0.057500 -0.020889  0.196667  0.035338 -0.057043
# 1.0    67308.333333 -5.381276  3.958775 -7.454069  4.655050 -3.775485
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.033051 -0.015454  0.002819  0.007174  ...  0.009268 -0.008029
# 1.0   -1.357987 -6.264641  0.663762 -2.696376  ...  0.376889  0.765659
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.022989 -0.009829  0.001235  0.038078  0.002754 -0.000146  0.001861
# 1.0    0.013088 -0.060036 -0.083433  0.051373  0.037788  0.202087  0.057439
#
#            Amount
# Class
# 0.0     90.768591
# 1.0    125.656379
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)
new_df = pd.concat([legit_sample,fraud],axis=0)
new_df
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 7515   10268 -1.289700  0.131813  2.307909 -1.339342 -1.190684 -0.588385
# 30637  36020 -0.995966  0.137682  1.576352 -1.906005 -0.282327 -0.883683
# 50834  44669 -2.792152  1.783917  0.626692 -1.301687 -0.861837  1.272737
# 40658  40340 -0.521156  0.205919  2.201131  0.444069 -0.252112  0.343828
# 35765  38252  1.274539  0.063162 -1.187443  0.070124  2.188223  3.385918
# ...      ...       ...       ...       ...       ...       ...       ...
# 46998  43028 -1.109646  0.811069 -1.138135  0.935265 -2.330248 -0.116106
# 47802  43369 -3.365319  2.426503 -3.752227  0.276017 -2.305870 -1.961578
# 48094  43494 -1.278138  0.716242 -1.143279  0.217805 -1.293890 -1.168952
# 50211  44393 -4.617461  3.663395 -5.297446  3.880960 -3.263551 -0.918547
# 50537  44532 -0.234922  0.355413  1.972183 -1.255593 -0.681387 -0.665732
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 7515  -0.883165  0.547598  0.570625  ...  0.225541  0.706048 -0.298993
# 30637  0.446020 -0.457621 -1.172164  ...  0.417364  1.297902 -0.094570
# 50834 -1.497275 -1.981745  0.776531  ...  2.830993 -1.378219  0.279050
# 40658 -0.197884  0.507216  0.322365  ...  0.125155  0.376397  0.051739
# 35765 -0.439015  0.797504 -0.147842  ...  0.021788 -0.055103 -0.151738
# ...         ...       ...       ...  ...       ...       ...       ...
# 46998 -1.621986  0.458028 -0.912189  ...  0.641594  0.841755  0.176728
# 47802 -3.029283 -1.674462  0.183961  ...  2.070008 -0.512626 -0.248502
# 48094 -2.564182  0.204532 -1.611155  ...  0.490183  0.470427 -0.126261
# 50211 -5.715262  0.831040 -2.457034  ...  2.698175 -0.027081  0.366775
# 50537  0.059110 -0.003153  1.122451  ...  0.220670  0.912107 -0.286338
#
#             V24       V25       V26       V27       V28  Amount  Class
# 7515   0.356857  0.512670 -0.150602  0.154197  0.011899   22.00    0.0
# 30637  0.579426  0.006495 -0.349419 -0.521132 -0.151520   15.00    0.0
# 50834 -0.923051  0.182514  0.927611  0.375478  0.005611   38.99    0.0
# 40658  0.186776 -0.321683 -0.583705  0.082176  0.026492   19.00    0.0
# 35765  1.007977  0.830686 -0.266242  0.019198  0.016630   12.00    0.0
# ...         ...       ...       ...       ...       ...     ...    ...
# 46998  0.081004 -0.258899  0.707654  0.418649  0.080756  204.27    1.0
# 47802  0.126550  0.104166 -1.055997 -1.200165 -1.012066   88.00    1.0
# 48094 -0.126644 -0.661908 -0.349793  0.454851  0.137843   24.90    1.0
# 50211 -0.123011 -0.300457 -0.239996 -0.183463 -0.073360    1.00    1.0
# 50537  0.451208  0.188315 -0.531846  0.123185  0.039581    1.00    1.0
#
# [642 rows x 31 columns]

# %%
new_df['Class'].value_counts()
# Out:
# 0.0    492
# 1.0    150
# Name: Class, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    29098.587398 -0.298442 -0.138273   0.626780  0.063103 -0.227045
# 1.0    27111.653333 -7.605033  5.403059 -10.281767  5.877956 -5.631727
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.185791 -0.037833  0.099160  0.142454  ...  0.168181 -0.006179
# 1.0   -2.260874 -7.999087  3.694993 -3.548144  ...  0.461715  0.894469
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.162654 -0.046243  0.026118  0.097814  0.037062 -0.007885  0.003531
# 1.0   -0.216422 -0.280400 -0.081415  0.242705  0.148260  0.594727  0.030024
#
#            Amount
# Class
# 0.0    130.365427
# 1.0     98.848400
#
# [2 rows x 30 columns]

# %%
X = new_df.drop(columns='Class', axis=1)
Y = new_df['Class']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
#logisticregression
model=LogisticRegression()

# %%
# training the Logistic Regression Model
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9767441860465116

# %%
# accuracy on train data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Train data : ', training_data_accuracy)
# Out:
# Accuracy on Train data :  0.9766081871345029
